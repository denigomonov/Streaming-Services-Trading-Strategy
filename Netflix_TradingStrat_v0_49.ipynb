# %%
import pandas as pd
import numpy as np
import fix_yahoo_finance as fyf
from pandas_datareader import data as web
from datetime import datetime
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
#fetching data
fyf.pdr_override()
today_date=datetime.today().strftime('%Y-%m-%d')
yf_data=web.get_data_yahoo('NFLX', start = '2013-01-01', end = today_date)
#bitcoin dataframe
netflix_df=pd.DataFrame(yf_data)
netflix_df.reset_index(inplace=True)
netflix_df
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2013-01-02   13.601429   13.687143  ...   13.144286   13.144286  19431300
# 1    2013-01-03   13.138571   13.988571  ...   13.798571   13.798571  27912500
# 2    2013-01-04   13.791429   13.958571  ...   13.711429   13.711429  17761100
# 3    2013-01-07   13.770000   14.535714  ...   14.171429   14.171429  45550400
# 4    2013-01-08   14.287143   14.427143  ...   13.880000   13.880000  24714900
# ...         ...         ...         ...  ...         ...         ...       ...
# 2127 2021-06-15  501.230011  501.230011  ...  491.899994  491.899994   3104100
# 2128 2021-06-16  495.000000  496.459991  ...  492.410004  492.410004   3533200
# 2129 2021-06-17  490.250000  501.799988  ...  498.339996  498.339996   3198300
# 2130 2021-06-18  496.399994  504.489990  ...  500.769989  500.769989   5194200
# 2131 2021-06-21  501.640015  502.019989  ...  497.000000  497.000000   5277297
#
# [2132 rows x 7 columns]

# %%
#checking for null values
netflix_df.rename(columns={"Adj Close": "Adj_Close"}, inplace=True)
netflix_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### **Feature Engineering**

# %%
#simple moving average 10,30 days
def SMA(df, x):
  SMA_calc=df.Adj_Close.rolling(window=x, min_periods=x).mean()
  return SMA_calc
netflix_df['SMA10']=SMA(netflix_df,10)
netflix_df['SMA30']=SMA(netflix_df,30)

#exponential moving average 20,30,200 days
def EMA(df, x):
  EMA_calc=df.Adj_Close.ewm(span=x, min_periods=x, adjust=False).mean()
  return EMA_calc

netflix_df['EMA20']=EMA(netflix_df,20)
netflix_df['EMA30']=EMA(netflix_df,30)
netflix_df['EMA200']=EMA(netflix_df,200)
#netflix_df['EMA20']=netflix_df.Adj_Close.ewm(span=20, min_periods=20, adjust=False).mean()

# %%
#rate of change ROC 10,30 days
def ROC(df, n):
  ROC_diff=df.Adj_Close.diff(n)
  ROC_shift=df.Adj_Close.shift(n)
  #roc formula
  ROC_calc=((ROC_diff/ROC_shift)*100)
  return ROC_calc
  
netflix_df['ROC10']=ROC(netflix_df,10)
netflix_df['ROC30']=ROC(netflix_df,30)

# %%
#volume rate of change 10,30 days
def VROC(df, n):
  VROC_diff=df.Volume.diff(n)
  VROC_shift=df.Volume.shift(n)
  #roc formula
  VROC_calc=((VROC_diff/VROC_shift)*100)
  return VROC_calc
  
netflix_df['VROC10']=VROC(netflix_df,10)
netflix_df['VROC30']=VROC(netflix_df,30)

# %%
#relative strength index RSI 14 days
def RSI(df, n=14):
  delta=df.Adj_Close.diff()
  dup, ddown=delta.copy(), delta.copy()
  #average gains and losses
  dup[dup<0]=0
  ddown[ddown>0]=0
  rolup=dup.rolling(window=n, min_periods=n).mean()
  roldown=ddown.rolling(window=n, min_periods=n).mean().abs()
  #relative strength
  RS_calc=rolup/roldown
  #rsi formula
  RSI_calc=(100-(100/(1+RS_calc)))
  return RSI_calc

netflix_df['RSI14']=RSI(netflix_df)

# %%
#RSI indicators %30 %70
def RSI_Ind(df):
  rsi_vals=[]
  for i in df['RSI14'].iloc[:]:
    if i <= 30:
      rsi_vals.append(0)
    elif i >= 70:
      rsi_vals.append(1)
    else:
      rsi_vals.append(2)
  return rsi_vals

netflix_df['RSI14_IND']=RSI_Ind(netflix_df)

# %%
#STO%K%D Stochastic oscillator 14,200 days
def STOK(close, low, high, n):
  STOK_calc=((close-low.rolling(n).min())/(high.rolling(n).max()-low.rolling(n).min()))*100
  return STOK_calc

netflix_df['STOK14']=STOK(netflix_df.Adj_Close, netflix_df.Low, netflix_df.High, 14)
netflix_df['STOK200']=STOK(netflix_df.Adj_Close, netflix_df.Low, netflix_df.High, 200)

def STOD(stod, n):
  STOD_calc=stod.rolling(3).mean()
  return STOD_calc

netflix_df['STOD14']=STOD(netflix_df.STOK14, 14)
netflix_df['STOD14']=STOD(netflix_df.STOK200, 200)

# %%
#bollinger bands upper
def BBandsUp(close, n, mult):
  BBandsUp_calc=close.rolling(window=n, min_periods=n).mean() + close.rolling(window=n, min_periods=n).std() * mult
  return BBandsUp_calc

netflix_df['BBandUpper']=BBandsUp(netflix_df.Adj_Close,20,2)
#bollinger bands lower
def BBandsLow(close, n, mult):
  BBandsLow_calc=close.rolling(window=n, min_periods=n).mean() - close.rolling(window=n, min_periods=n).std() * mult
  return BBandsLow_calc

netflix_df['BBandLower']=BBandsLow(netflix_df.Adj_Close,20,2)

# %%
#filling NaNs of feature engineered columns at the end not to alter calculations
netflix_df.fillna(method='bfill', inplace=True)

# %%
#dataframe after feature engineering phase
netflix_df
# Out:
#            Date        Open        High  ...     STOD14  BBandUpper  BBandLower
# 0    2013-01-02   13.601429   13.687143  ...  97.397107   24.702632    8.040940
# 1    2013-01-03   13.138571   13.988571  ...  97.397107   24.702632    8.040940
# 2    2013-01-04   13.791429   13.958571  ...  97.397107   24.702632    8.040940
# 3    2013-01-07   13.770000   14.535714  ...  97.397107   24.702632    8.040940
# 4    2013-01-08   14.287143   14.427143  ...  97.397107   24.702632    8.040940
# ...         ...         ...         ...  ...        ...         ...         ...
# 2127 2021-06-15  501.230011  501.230011  ...  25.926201  508.170545  482.828451
# 2128 2021-06-16  495.000000  496.459991  ...  26.827039  507.817443  483.794554
# 2129 2021-06-17  490.250000  501.799988  ...  26.443438  507.766116  484.909879
# 2130 2021-06-18  496.399994  504.489990  ...  28.638601  507.639506  484.946487
# 2131 2021-06-21  501.640015  502.019989  ...  29.774542  507.575597  484.921394
#
# [2132 rows x 23 columns]

# %% [markdown]
# ### **Data Visualization**

# %%
#NFLX Chart
candle_fig=make_subplots(rows=2, cols=1,
                         row_heights=[0.7,0.3],
                         vertical_spacing=0.08,
                         )

#BBands traces
candle_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['BBandUpper'],
                                mode='lines', name='BBandUpper', 
                                marker_color='rgb(175, 175, 182)',
                                ),row=1, col=1)
candle_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['BBandLower'],
                                mode='lines', name='BBandLower', 
                                marker_color='rgb(175, 175, 182)',
                                fillcolor='rgba(175, 175, 182, 0.2)',
                                fill='tonexty'
                                ),row=1, col=1)
#Candle trace
candle_fig.add_trace(go.Candlestick(x=netflix_df['Date'],
                                    open=netflix_df['Open'],
                                    high=netflix_df['High'],
                                    low=netflix_df['Low'],
                                    close=netflix_df['Close'],
                                    name='NFLX',
                                    increasing_line_color= 'rgb(0, 230, 0)',
                                    decreasing_line_color= 'rgb(255, 0, 0)'
                                    ),row=1, col=1)
#SMA traces
candle_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['SMA10'],
                                mode='lines', name='SMA10', 
                                marker_color='rgb(255, 153, 0)',
                                visible='legendonly'
                                ),row=1, col=1)
candle_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['SMA30'],
                                mode='lines', name='SMA30', 
                                marker_color='rgb(255, 191, 0)',
                                visible='legendonly'
                                ),row=1, col=1)
#EMA traces
candle_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['EMA20'],
                                mode='lines', name='EMA20', 
                                marker_color='rgb(128, 255, 0)',
                                visible='legendonly'
                                ),row=1, col=1)
candle_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['EMA30'],
                                mode='lines', name='EMA30', 
                                marker_color='rgb(64, 255, 0)',
                                visible='legendonly'
                                ),row=1, col=1)
candle_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['EMA200'],
                                mode='lines', name='EMA200', 
                                marker_color='rgb(0, 255, 64)'
                                ),row=1, col=1)
#Volume trace
candle_fig.add_trace(go.Bar(x=netflix_df['Date'],
                            y=netflix_df['Volume'],
                            name='Volume',
                            marker_color='rgb(255, 255, 0)'
                            ),row=2, col=1)

#customization
candle_fig.update_layout(
    template='plotly_dark',
    yaxis=dict(title_text='Currency in USD', title_standoff=5),
    autosize=False,
    width=1400,
    height=800,
    xaxis_rangeslider_visible=False,
    title_text='Netflix(NFLX) NasdaqGS - Chart',
    title_x=0.5)
candle_fig.update_yaxes(title_text='Volume', row=2, col=1,
                        title_standoff=1)

candle_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="81dc8eaa-222c-4766-9a0c-eec753eb790c" class="plotly-graph-div" style="height:800px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById
013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "20 ...

# %%
#RSI Chart
rsi_fig=make_subplots(rows=1, cols=2,
                      column_widths=[0.7,0.3],
                      horizontal_spacing=0.05,
                      )
#rsi14 trace
rsi_fig.add_trace(go.Scatter(x=netflix_df['Date'],
                                y=netflix_df['RSI14'],
                                mode='lines', name='RSI14', 
                                marker_color='rgb(26, 140, 255)',
                                ),row=1, col=1)

#indicators trace
ind=netflix_df.RSI14_IND.to_list()
oversold_list=list(filter(lambda a: a == 0, ind))
rsi_fig.add_trace(go.Histogram(x=oversold_list,
                               name='Oversold',
                               marker_color='rgb(255, 255, 255)',
                               marker_line_color='rgb(26, 140, 255)',
                               marker_line_width=2,
                               opacity=0.75
                               ),row=1, col=2)
overvalued_list=list(filter(lambda a: a == 1, ind))
rsi_fig.add_trace(go.Histogram(x=overvalued_list,
                               name='Overbought',
                               marker_color='rgb(128, 128, 128)',
                               marker_line_color='rgb(26, 140, 255)',
                               marker_line_width=2,
                               opacity=0.75
                               ),row=1, col=2)
#customization
rsi_fig.update_layout(
    template='plotly_dark',
    yaxis=dict(title_text='RSI',
               title_standoff=5,
               tickvals=[30,70]),
    autosize=False,
    width=1400,
    height=600,
    title_text='Netflix(NFLX) Relative Strength Index (14 Days) & Indicators - Chart',
    title_x=0.5)
rsi_fig.update_xaxes(visible=False, row=1, col=2)

rsi_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6198c10e-9385-4138-8a28-7158ebde3017" class="plotly-graph-div" style="height:600px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6198c10e-9385-4138-8a28-7158ebde3017")) {
#                     Plotly.newPlot(
#                         '6198c10e-9385-4138-8a28-7158ebde3017',
#                         [{"marker": {"color": "rgb(26, 140, 255)"}, "mode": "lines", "name": "RSI14", "type": "scatter", "x": ["2013-01-02T00:00:00", "2013-01-03T00:00:00", "2013-01-04T00:00:00", "2013-01-07T00:00:00", "2013-01-08T00:00:00", "2013-01-09T00:00:00", "2013-01-10T00:00:00", "2013-01-11T00:00:00", "2013-01-14T00:00:00", "2013-01-15T00:00:00", "2013-01-16T00:00:00", "2013-01-17T00:00:00", "2013-01-18T00:00:00", "2013-01-22T00:00:00", "2013-01-23T00:00:00", "2013-01-24T00:00:00", "2013-01-25T00:00:00", "2013-01-28T00:00:00", "2013-01-29T00:00:00", "2013-01-30T00:00:00", "2013-01-31T00:00:00", "2013-02-01T00:00:00", "2013-02-04T00:00:00", "2013-02-05T00:00:00", "2013-02-06T00:00:00", "2013-02-07T00:00:00", "2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-26T00:00:00", "2013-02-27T00:00:00", "2013-02-28T00:00:00", "2013-03-01T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03
#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row8_col8,#T_fedd4e6a_d2ff_11eb_ ...
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row0_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row2_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row3_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row4_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row6_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row7_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row7_col11,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row7_col15,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row7_col17,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row8_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row9_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col5,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col11{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row0_col10,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row1_col10,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row2_col10,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row3_col10,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row4_col10,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col0,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col1,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col2,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col3,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col4{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row0_col11,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row2_col12,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row3_col12,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row4_col12,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row10_col14{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row0_col12,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row1_col12,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row21_col14{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row0_col13,#T_fedd4e6a_d2ff_11eb_bdbe_0242ac1c0002row3_col13,#T_f

# %%
#selecting only columns that have strongest linear associations
netflix_ml_df=netflix_df[['Adj_Close', 'SMA10', 'SMA30', 'EMA20', 'EMA30', 'EMA200', 'BBandUpper', 'BBandLower']]
corr2=netflix_ml_df.corr(method='pearson')
corr2.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col0,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col1,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col2,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col3,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col4,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col5,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col6,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col1,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col4,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col1{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col2{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col3,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col0,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col2{
#             background-color:  #f08a6c;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col4{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col5,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col0,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col1,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col2,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col3,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col4,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col6,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row5_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col6,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col0{
#             background-color:  #f7a889;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col7{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col0{
#             background-color:  #d95847;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col2,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col2{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col3{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col5{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col6,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col3{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row1_col7{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col1,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col6{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col3{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col4,#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col2{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col5{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row2_col7{
#             background-color:  #e8765c;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col0{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col1{
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col2{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col4{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col5{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col6{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row3_col7{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col1{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col3{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col5{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col6{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row4_col7{
#             background-color:  #e9785d;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col0{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col4{
#             background-color:  #eb7d62;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col5{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row6_col7{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col0{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col1{
#             background-color:  #f29274;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col3{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col4{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col5{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row7_col6{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }</style><table id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Adj_Close</th>        <th class="col_heading level0 col1" >SMA10</th>        <th class="col_heading level0 col2" >SMA30</th>        <th class="col_heading level0 col3" >EMA20</th>        <th class="col_heading level0 col4" >EMA30</th>        <th class="col_heading level0 col5" >EMA200</th>        <th class="col_heading level0 col6" >BBandUpper</th>        <th class="col_heading level0 col7" >BBandLower</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002level0_row0" class="row_heading level0 row0" >Adj_Close</th>
#                         <td id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col1" class="data row0 col1" >0.997857</td>
#                         <td id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col2" class="data row0 col2" >0.994406</td>
#                         <td id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col3" class="data row0 col3" >0.997165</td>
#                         <td id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col4" class="data row0 col4" >0.995913</td>
#                         <td id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col5" class="data row0 col5" >0.980629</td>
#                         <td id="T_feea18fc_d2ff_11eb_bdbe_0242ac1c0002row0_col6" class="data row0 col6" >0.995274</td>

# %%
#getting correct indexs
last_ind=netflix_ml_df.tail(1).index.item()
starting_ind=last_ind-63
#only last 3 months worth of data (63 days on average)
netflix_mlr_df=netflix_ml_df.loc[starting_ind:last_ind, :]

# %%
netflix_mlr_df.reset_index(inplace=True)
netflix_mlr_df.drop('index', axis=1, inplace=True)
netflix_mlr_df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Adj_Close       SMA10       SMA30  ...      EMA200  BBandUpper  BBandLower
# 0   523.109985  516.086005  533.389006  ...  495.018395  559.205503  489.408505
# 1   535.090027  518.951007  532.961340  ...  495.417118  557.527521  489.980487
# 2   520.809998  520.578006  531.686007  ...  495.669783  552.883317  491.364693
# 3   502.859985  518.558005  529.661672  ...  495.741328  549.544119  490.319889
# 4   508.049988  517.561002  528.010337  ...  495.863802  547.049797  489.734212
# ..         ...         ...         ...  ...         ...         ...         ...
# 59  491.899994  492.409998  494.945331  ...  501.116116  508.170545  482.828451
# 60  492.410004  491.726999  494.586331  ...  501.029488  507.817443  483.794554
# 61  498.339996  492.617999  494.661665  ...  501.002727  507.766116  484.909879
# 62  500.769989  493.220999  494.702332  ...  501.000411  507.639506  484.946487
# 63  497.000000  493.454999  494.474332  ...  500.960606  507.575597  484.921394
#
# [64 rows x 8 columns]

# %%
y_lr=netflix_mlr_df['Adj_Close']
X_lr=netflix_mlr_df[['SMA10', 'SMA30', 'EMA20', 'EMA30', 'EMA200', 'BBandUpper', 'BBandLower']]

# %%
#multiple linear regression
from sklearn.linear_model import LinearRegression
linear_regression=LinearRegression()

# %%
x_train, x_test,y_train,y_test = train_test_split(X_lr,y_lr,test_size=0.1)
#fitting
linear_regression.fit(x_train, y_train)
#prediction
pred=linear_regression.predict(x_test)

#score
linear_regression.score(X_lr, y_lr)
# Out:
# 0.9145575555921714

# %%
co=linear_regression.coef_
co
# Out:
# array([-2.91968851, -0.41948696, 13.14401423, -7.14888872, -0.41379767,
#        -1.01791537, -0.91560506])

# %%
inter=linear_regression.intercept_
inter
# Out:
# 358.11922076955375

# %% [markdown]
# [<img src="https://csharpcorner-mindcrackerinc.netdna-ssl.com/article/linear-regression2/Images/f_MLR.png">]

# %%
y=inter+co[0]*(64)+co[1]*(64)+co[2]*(64)+co[3]*(64)+co[4]*(64)+co[5]*(64)+co[6]*(64)
y
# Out:
# 463.0939144539567

# %%
pred
# Out:
# array([522.09153817, 495.03581818, 545.38202517, 503.23437408,
#        495.88397122, 526.26999634, 498.90574136])

# %%
y_test
# Out:
# 1     535.090027
# 59    491.899994
# 16    540.020020
# 25    505.549988
# 61    498.339996
# 8     539.419983
# 44    502.899994
# Name: Adj_Close, dtype: float64
